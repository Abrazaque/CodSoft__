# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split as tts
from sklearn.metrics import confusion_matrix
from sklearn.svm import SVC

# %%
df=pd.read_csv(r'C:\Users\Razaque\Downloads\advertising.csv')
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
sns.scatterplot(x='TV',y='Sales',data=df,marker='+',color='green')
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
sns.scatterplot(x='Radio',y='Sales',data=df,marker='D',color='blue')
# Out:
# <Axes: xlabel='Radio', ylabel='Sales'>

# %%
sns.scatterplot(x='Newspaper',y='Sales',data=df,marker='o',color='purple')
# Out:
# <Axes: xlabel='Newspaper', ylabel='Sales'>

# %%
plt.figure(figsize=(8, 6))
sns.pairplot(df, )

# %%
sns.catplot(data=df, kind='box',height=5,aspect=1.2)

# %%
X=df.drop(['Sales'],axis='columns')
y=df['Sales']

# %%
X_train,X_test,y_train,y_test=tts(X,y, test_size=0.2)

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pre=model.score(X_test,y_test)
print(f'Linear Regression Model Accuracy :{y_pre*100:.2f}')
# Out:
# Linear Regression Model Accuracy :92.77

# %%
predicted_values=model.predict(X_test)
for i in predicted_values:
    print(i)
# Out:
# 10.265159710376532
# 20.154260173678146
# 17.80248589294716
# 17.326016954882533
# 9.346082631815499
# 10.644713932725967
# 19.15791353094776
# 16.815530550191916
# 10.613787210426263
# 18.81261960465801
# 9.794454866856025
# 9.846775777422444
# 20.726904086674878
# 18.796096191605958
# 12.65909356565459
# 16.91222269648028
# 21.31905464964578
# 10.38877877934166
# 15.476719991761557
# 11.634756760437595
# 13.881959245016013
# 10.212401402322207
# 7.785362464964887
# 12.522131629145163
# 9.500464137465023
# 23.68288992781015
# 19.51851334824999
# 8.852038763941422
# 24.85728669696067
# 22.678439922122408
# 20.31654965080577
# 14.908793547302263
# 6.929134359616546
# 11.787636876506294
# 15.149437752927213
# 13.7740686224064
# 16.445422397244645
# 24.583339375707006
# 21.239830072596057
# 10.991915469823208
